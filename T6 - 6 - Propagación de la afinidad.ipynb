# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
# Out:
# C:\Users\PC GAMER\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
centros = [[1,1], [-1,-1], [1,-1]]
X, labels = make_blobs(n_samples=300, centers=centros, cluster_std=0.5, random_state=0)

# %%
import matplotlib.pyplot as plt
from itertools import cycle

# %%
plt.scatter(X[:,0], X[:,1], c=labels, s=5, cmap="autumn")

# %%
af = AffinityPropagation(preference=-50).fit(X)
# Out:
# C:\Users\PC GAMER\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:146: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 0.25 which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(("'random_state' has been introduced in 0.23. "

# %%
cluster_center_ids = af.cluster_centers_indices_

# %%
labels = af.labels_

# %%
n_clust= len(cluster_center_ids)
n_clust
# Out:
# 3

# %%
def report_affinity_propagation(af):
    n_clust = len(cluster)
    print("Número estimado de clusters: %d"%n_clust)
