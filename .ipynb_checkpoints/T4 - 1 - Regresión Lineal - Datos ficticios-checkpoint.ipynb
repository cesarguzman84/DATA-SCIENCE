# %% [markdown]
# # Modelo de Regresión Lineal
# ## Modelo con datos simulados
# * y = a + b * x
# * x: 100 valores distribuidos segun una N(1.5, 2.5)
# * Ye = 5 + 1.9 * x + e
# * e estara distribuido segun una N(0, 0.8)

# %%
import pandas as pd
import numpy as np

# %%
x = 1.5 + 2.5 * np.random.rand(100)

# %%
res = 0 + 0.8 *np.random.randn(100)

# %%
y_pred = 5 + 1.9*x

# %%
y_act = 5 + 1.9 * x + res

# %%
x_lista = x.tolist()
y_pred_lista = y_pred.tolist()
y_act_lista = y_act.tolist()

# %%
datos = pd.DataFrame(
    {
        "x" : x_lista,
        "y_actual" : y_act_lista,
        "y_prediccion" : y_pred_lista
    }
)

# %%
datos.head()
# Out:
#           x  y_actual  y_prediccion
# 0  1.872986  9.630893      8.558672
# 1  2.047759  8.690703      8.890743
# 2  1.998772  9.440298      8.797667
# 3  2.723802  8.536708     10.175224
# 4  1.956971  9.494879      8.718245

# %%
import matplotlib.pyplot as plt

# %%
y_promedio = [np.mean(y_act) for i in range (1, len(x_lista)+1)]

# %%
# %matplotlib inline
plt.plot(x, y_pred)
plt.plot (x, y_act, "ro")
plt.plot (x, y_promedio, "g")
plt.title("Valor Actual vs Predicción")
# Out:
# Text(0.5, 1.0, 'Valor Actual vs Predicción')

# %%
datos ["SSR"] = (datos["y_prediccion"] - np.mean(y_act))**2
datos ["SSD"] = (datos["y_prediccion"] - datos ["y_actual"])**2
datos ["SST"] = (datos["y_actual"] - np.mean(y_act))**2

# %%
datos.head()
# Out:
#           x  y_actual  y_prediccion       SSR       SSD       SST
# 0  1.872986  9.630893      8.558672  2.474465  1.149657  0.250823
# 1  2.047759  8.690703      8.890743  1.540014  0.040016  2.076517
# 2  1.998772  9.440298      8.797667  1.779685  0.412974  0.478059
# 3  2.723802  8.536708     10.175224  0.001893  2.684734  2.544051
# 4  1.956971  9.494879      8.718245  1.997901  0.603161  0.405561

# %%
SSR = sum(datos["SSR"])
SSD = sum(datos["SSD"])
SST = sum(datos["SST"])

# %%
SSR
# Out:
# 195.21183516565443

# %%
SSD
# Out:
# 85.11026214467311

# %%
SST
# Out:
# 222.11428585132452

# %%
SSR+SSD
# Out:
# 280.32209731032754

# %%
R2 = SSR/SST

# %%
R2
# Out:
# 0.878880142344029

# %%
plt.hist(datos["y_prediccion"] - datos ["y_actual"])
# Out:
# (array([ 6.,  5., 13., 10., 10., 20.,  8., 12.,  9.,  7.]),
#  array([-1.83236199, -1.46825082, -1.10413965, -0.74002848, -0.37591731,
#         -0.01180614,  0.35230503,  0.7164162 ,  1.08052737,  1.44463854,
#          1.80874971]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Obteniendo la recta de regresión

# %%
x_promedio = np.mean(datos["x"])
y_promedio = np.mean(datos["y_actual"])
x_promedio, y_promedio
# Out:
# (2.718967187811393, 10.131715715678801)

# %%
datos["beta_n"] = (datos["x"]-x_promedio)*(datos["y_actual"]-y_promedio)
datos["beta_d"] = (datos["x"]-x_promedio)**2

# %%
beta= sum(datos["beta_n"])/sum(datos["beta_d"])

# %%
alpha = y_promedio - beta * x_promedio

# %%
alpha, beta
# Out:
# (5.73322236388017, 1.6177074043100745)

# %% [markdown]
# El modelo lineal optenido por regresión es:
# y=5.73322236388017 + 1.6177074043100745*x

# %%
datos["y_modelo"] =alpha + beta * datos["x"]

# %%
datos.head()
# Out:
#           x  y_actual  y_prediccion       SSR       SSD       SST    beta_n  \
# 0  1.872986  9.630893      8.558672  2.474465  1.149657  0.250823  0.423687
# 1  2.047759  8.690703      8.890743  1.540014  0.040016  2.076517  0.967219
# 2  1.998772  9.440298      8.797667  1.779685  0.412974  0.478059  0.497956
# 3  2.723802  8.536708     10.175224  0.001893  2.684734  2.544051 -0.007711
# 4  1.956971  9.494879      8.718245  1.997901  0.603161  0.405561  0.485267
#
#      beta_d   y_modelo
# 0  0.715685   8.763165
# 1  0.450520   9.045898
# 2  0.518681   8.966651
# 3  0.000023  10.139537
# 4  0.580639   8.899029

# %%
SSR = sum ((datos["y_modelo"] -y_promedio)**2)
SSD = sum ((datos["y_modelo"] - datos ["y_actual"])**2)
SST = sum((datos["y_actual"] - y_promedio)**2)

# %%
SSR, SSD, SST
# Out:
# (141.42843545446323, 80.68585039686145, 222.11428585132458)

# %%
R2 = SSR/SST
R2
# Out:
# 0.6367372315220211

# %%
y_promedio = [np.mean(y_act) for i in range (1, len(x_lista)+1)]
# %matplotlib inline
plt.plot(x, y_pred)
plt.plot (x, y_act, "ro")
plt.plot (x, y_promedio, "g")
plt.plot(datos["x"], datos["y_modelo"])
plt.title("Valor Actual vs Predicción")
# Out:
# Text(0.5, 1.0, 'Valor Actual vs Predicción')
