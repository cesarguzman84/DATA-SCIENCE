# %% [markdown]
# # Dividir el dataset en conjunto de entrenamiento y de testing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv(r"E:\VARIOS\python-ml-course-master\datasets\ads\Advertising.csv")

# %%
a = np.random.randn(len(datos))

# %%
plt.hist(a)
# Out:
# (array([ 4., 17., 21., 26., 39., 33., 33., 13., 10.,  4.]),
#  array([-2.44415855, -1.94813013, -1.4521017 , -0.95607328, -0.46004486,
#          0.03598357,  0.53201199,  1.02804041,  1.52406884,  2.02009726,
#          2.51612569]),
#  <BarContainer object of 10 artists>)

# %%
check = (a<0.8)
training = datos [check]
testing = datos [~check]

# %%
len(training), len(testing)
# Out:
# (158, 42)

# %%
import statsmodels.formula.api as smf
modelo_lineal = smf.ols(formula="Sales~TV+Radio", data =training).fit()

# %%
modelo_lineal.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     733.5
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):           9.36e-80
# Time:                        10:25:12   Log-Likelihood:                -291.07
# No. Observations:                 158   AIC:                             588.1
# Df Residuals:                     155   BIC:                             597.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2014      0.307     10.419      0.000       2.594       3.808
# ...

# %% [markdown]
# ventas = 2.4823 + 0.0473 * TV + 0.1943 * Radio

# %% [markdown]
# ## Validacipon del modelo con elconjunto de testing

# %%
ventas_prediccion = modelo_lineal.predict(testing)
ventas_prediccion
# Out:
# 0      20.434614
# 7      12.175030
# 18     10.176651
# 20     17.953051
# 28     19.131771
# 36     23.181830
# 37     16.084149
# 39     20.325424
# 43     13.674100
# 46      8.970204
# 47     21.578857
# 48     15.992439
# 53     20.057717
# 55     21.381024
# 72     10.822069
# 76      4.688251
# 78      9.300888
# 92     19.061710
# 101    22.967730
# 104    20.093029
# 107     7.115622
# 113    16.184052
# 118    15.805503
# 120    14.488228
# 126    11.169901
# 130    11.004507
# 132     8.898834
# 134    12.352067
# 136    11.948664
# 142    19.122235
# 143     8.781218
# 145     9.557827
# 149    10.172141
# 159    12.429927
# 161    13.883660
# 164    11.085240
# 175    24.609416
# 179    12.226812
# 182     6.717057
# 189     6.374049
# 190    12.953690
# 197    12.575592
# dtype: float64

# %%
SSD = sum(testing["Sales"]- ventas_prediccion)**2  #SSD = suma de los cuadrados de la diferencia
SSD
# Out:
# 10.934793841720017

# %%
RSE = np.sqrt(SSD/(len(testing)-2-1))
RSE
# Out:
# 0.5295085733723981

# %%
ventas_promedio = np.mean(testing["Sales"])
error = RSE/ ventas_promedio
error
# Out:
# 0.03742739831982618
