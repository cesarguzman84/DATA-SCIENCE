# %% [markdown]
# # Carga de datos a traves de la funcion read_csv

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\titanic\titanic3.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8e5a04cb6c46> in <module>
# ----> 1 data = pd.read_csv(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\titanic\titanic3.csv")
#
# ...

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# # Carga de datos a traves de la funcion open

# %%
data3=open(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\customer-churn-model\Customer Churn Model.txt")

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data3=open(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\customer-churn-model\Customer Churn Model.txt")

# %%
data3=open(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\customer-churn-model\Customer Churn Model.txt", "r")

# %%
cols =data3.readline().strip().split(",")
cols
# Out:
# ['AL',
#  '118',
#  '510',
#  '391-8027',
#  'yes',
#  'no',
#  '0',
#  '223.400000',
#  '98',
#  '37.980000',
#  '220.600000',
#  '101',
#  '18.750000',
#  '203.900000',
#  '118',
#  '9.180000',
#  '6.300000',
#  '6',
#  '1.700000',
#  '0',
#  'False.']

# %%
n_cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9a0ac2e661e0> in <module>
# ----> 1 n_cols
#
# NameError: name 'n_cols' is not defined

# %%
ncols=len(cols)

# %%
cols
# Out:
# ['AL',
#  '118',
#  '510',
#  '391-8027',
#  'yes',
#  'no',
#  '0',
#  '223.400000',
#  '98',
#  '37.980000',
#  '220.600000',
#  '101',
#  '18.750000',
#  '203.900000',
#  '118',
#  '9.180000',
#  '6.300000',
#  '6',
#  '1.700000',
#  '0',
#  'False.']

# %%
len(cols)
# Out:
# 21

# %% [markdown]
# # Lectura y escritura de ficheros

# %%
infile= r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\customer-churn-model\Customer Churn Model.txt"

# %%
outfile=r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\customer-churn-model\Tab Customer Churn Model.txt", "r"

# %% [markdown]
# # Leer datos desde URL

# %%
medals_url = "http://winterolympicsmedals.com/medals.csv"

# %%
medals_data=pd.read_csv(medals_url)

# %%
medals_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# # Ficheros XLS y XLSX

# %%
titancic2=pd.read_excel(r"C:\Users\PC GAMER\OneDrive\PROGRAMACION\DATA SCIENCE\MACHINE LEARNING CON PYTHON\python-ml-course\datasets\titanic\titanic3.xls", "titanic3")
